# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center">Lesson 01: Image Classification (Cats vs Dogs)</h1>
#     <h3 align="center">Javad Mohammadzadeh</h3>
# </div>

# %% [markdown]
# <h6 align='center'>Kaggle competition: [Dogs vs. Cats](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition)</h6>

# %% [markdown]
# <img src='C:/Users/Leila/Desktop/992/deep/imgs/catsanddogs.png' width='90%'/>

# %% [markdown]
# ## Objectives

# %% [markdown]
# - Image classification
# - Four key components of any ML system (in PyTorch):
#  - Data (Images)
#  - Model (CNN)
#  - Loss (Cross Entropy)
#  - Optimization (SGD, Adam, ..)
# - Convolutional Neural Networks (CNNs)
# - Overfit
# - Data augmentation
# - Transfer learning

# %% [markdown]
# ## Image Classification

# %% [markdown]
# <img src='imgs/Image_tasks.jpg' width='80%'/>

# %% [markdown]
# ## Libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import math
import time
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
import sys
#print(sys.path)
sys.path.append('C:\\prg\\deep\\week1')
# Our libraries
from train import train_model
from model_utils import *
from predict_utils import *
from vis_utils import *

# some initial setup
np.set_printoptions(precision=2)
use_gpu = torch.cuda.is_available()
np.random.seed(1234)

# %%
use_gpu
# Out:
# False

# %% [markdown]
# ## Data

# %% [markdown]
# - train: learning the **parameters** of the model.
# - valid: learning **hyper-parameters**.
# - test
# - development

# %%
# DATA_DIR = "D:/datasets/catsvsdogs/"
# DATA_DIR = "D:/datasets/catsvsdogs/dev/"

#DATA_DIR="c:/prg/deep/fastai-datasets-cats-vs-dogs-2/"
DATA_DIR="c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/"

sz = 224
batch_size = 16

# %%
os.listdir(DATA_DIR)
# Out:
# ['train', 'valid']

# %%
trn_dir = f'{DATA_DIR}train'
val_dir = f'{DATA_DIR}valid'

# %%
os.listdir(trn_dir)
# Out:
# ['cats', 'dogs']

# %%
trn_fnames = glob.glob(f'{trn_dir}/*/*.jpg')
trn_fnames[:10]
# Out:
# ['c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.11737.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.2266.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.2921.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.3570.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.394.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.4600.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.4865.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\cats\\cat.9021.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\dogs\\dog.1402.jpg',
#  'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/sample/train\\dogs\\dog.1614.jpg']

# %%
img = plt.imread(trn_fnames[7])
plt.imshow(img);

# %% [markdown]
# ### Datasets and Dataloaders in PyTorch

# %% [markdown]
# - <h6>Dataset</h6>A set of images.
# - <h6>Dataloader</h6>Loads data from dataset behind the scene using concurrent threads.

# %%
train_ds = datasets.ImageFolder(trn_dir)

# %%
train_ds.classes
# Out:
# ['cats', 'dogs']

# %%
train_ds.class_to_idx
# Out:
# {'cats': 0, 'dogs': 1}

# %%
train_ds.root
# Out:
# 'c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train'

# %%
train_ds.imgs
# Out:
# [('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.0.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.1.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.10.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.100.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.1000.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.101.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.102.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.104.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.105.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.106.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.107.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.108.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.109.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.11.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.111.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.112.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.113.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.114.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.115.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.116.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.117.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.119.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.12.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.120.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.121.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.122.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.123.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.124.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.126.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.128.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.129.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.13.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.130.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.131.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.133.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.134.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.135.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.136.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.137.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.138.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.139.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.14.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.140.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.141.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.142.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.143.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.144.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.145.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.146.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.148.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.149.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.15.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.151.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.152.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.153.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.154.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.156.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.157.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.158.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.159.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.16.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.160.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.161.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.162.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.163.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.164.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.165.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.166.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.167.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.168.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.169.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.17.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.170.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.171.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.172.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.174.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.175.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.176.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.177.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.178.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.179.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.18.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat
jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.597.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.598.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.599.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.6.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.60.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.601.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.605.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.606.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.607.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.608.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.609.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.61.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.610.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.611.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.612.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.613.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.614.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.615.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.616.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.617.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.618.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.619.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.62.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.620.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.621.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.622.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.623.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.624.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.625.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.626.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.627.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.628.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.629.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.63.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.630.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.632.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.633.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.634.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.635.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.636.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.637.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.638.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.639.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.64.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.640.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.642.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.643.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.644.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.645.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.646.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.647.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.648.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.649.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.65.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.650.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.651.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.652.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.653.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.654.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.655.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.656.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.657.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.658.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.659.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.66.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.660.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.661.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.662.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.663.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.664.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.665.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.666.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.667.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.668.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.669.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.67.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.670.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.671.jpg',
#   0),
# ...
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.888.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.889.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.89.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.890.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.891.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.892.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.893.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.894.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.895.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.896.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.897.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.898.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.899.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.9.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.90.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.900.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.901.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.902.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.903.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.904.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.905.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.907.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.909.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.91.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.910.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.911.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.912.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.913.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.914.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.915.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.916.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.917.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.918.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.919.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.920.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.922.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.923.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.924.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.925.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.926.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.927.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.928.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.929.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.93.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.930.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.931.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.932.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.933.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.934.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.935.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.936.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.937.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.938.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.939.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.94.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.940.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.941.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.942.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.943.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.944.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.945.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.946.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.947.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.948.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.949.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.95.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.950.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.951.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.952.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.955.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.956.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.957.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.958.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.959.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.96.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.960.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.961.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.962.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.963.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.964.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.966.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.967.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.968.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.969.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.97.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.970.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.971.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.972.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.973.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.975.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.976.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.977.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.978.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.979.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.98.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.980.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.981.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.982.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.983.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.984.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.985.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.986.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.987.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.988.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.989.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.99.jpg', 0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.990.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.991.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.992.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.993.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.995.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.996.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.997.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.998.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\cats\\cat.999.jpg',
#   0),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.0.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.1.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.10.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.100.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.1000.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.101.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.102.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.103.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.104.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.105.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.106.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.107.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.108.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.109.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.11.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.111.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.112.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.113.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.114.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.115.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.116.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.117.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.119.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.12.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.120.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.121.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.123.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.125.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.126.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.127.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.128.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.129.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.13.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.130.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.131.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.132.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.133.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.134.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.135.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.136.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.137.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.138.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.139.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.14.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.140.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.141.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.142.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.143.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.144.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.145.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.146.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.147.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.149.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.15.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.150.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.151.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.152.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.154.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.156.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.157.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.158.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.159.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.16.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.160.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.161.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.162.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.163.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.164.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.166.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.167.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.168.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.169.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.17.jpg', 1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.170.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.171.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.172.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.173.jpg',
#   1),
#  ('c:/prg/deep/fastai-datasets-cats-vs-dogs-2/dev/train\\dogs\\dog.174.jpg',
#   1),
#  ...]

# %%
# list(zip(*train_ds.imgs))

# %%
type(train_ds.transform)
# Out:
# NoneType

# %% [markdown]
# ### Transformations

# %% [markdown]
# Dataloader object uses these tranformations when loading data.

# %%
tfms = transforms.Compose([
    transforms.Resize((sz, sz)),  # PIL Image
    transforms.ToTensor(),        # Tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_ds = datasets.ImageFolder(trn_dir, transform=tfms)
valid_ds = datasets.ImageFolder(val_dir, transform=tfms)

# %%
print(len(train_ds), len(valid_ds))
type(train_ds.transform)
# Out:
# 1833 2000
# torchvision.transforms.transforms.Compose

# %% [markdown]
# #### Dataloaders

# %%
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, 
                                       shuffle=True, num_workers=4)
valid_dl = torch.utils.data.DataLoader(valid_ds, batch_size=batch_size, 
                                       shuffle=True, num_workers=4)

# %%
inputs, targets = next(iter(train_dl))
out = torchvision.utils.make_grid(inputs, padding=3)
plt.figure(figsize=(16, 12))
imshow(out, title='Random images from training data')

# %%
??imshow

# %% [markdown]
# ## Model: CNN

# %% [markdown]
# <img src='imgs/DogAndCats-CNN.jpg' width='100%'/>

# %%
class SimpleCNN(nn.Module):
    
    def __init__(self):
        super(SimpleCNN, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, padding=2),#2=(5-1)/2
            nn.BatchNorm2d(16),#sal 2015, ekhtiari hast, train ra saritar mikonad
            nn.ReLU(),# gheire khati, manfi 0 mishavad va mosbat baghi mimonanad
            nn.MaxPool2d(2)
        )
#size filter mamolan gam be gam kam mishvad        
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=5, padding=2),# az pahna va ertefa kam mishavd va be omgh ezafe mishavad
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc = nn.Linear(56 * 56 * 32, 2)
        
    def forward(self, x): #train mikonad
        out = self.conv1(x)
        out = self.conv2(out)            # (bs, C, H,  W)
        out = out.view(out.size(0), -1)  # (bs, C * H, W) #reshape dar numpy
        out = self.fc(out)
        return out

# %% [markdown]
# Now, it's time to create the model and to put it on the GPU.

# %%
model = SimpleCNN()

# transfer model to GPU
if use_gpu:
    model = model.cuda()
    print("cuda yes")

# %%
model
# Out:
# SimpleCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Linear(in_features=100352, out_features=2, bias=True)
# )

# %% [markdown]
# ## Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9) #stochastic gradian

# %% [markdown]
# ## Train

# %%
num_epochs = 10
losses = []
for epoch in range(num_epochs):
    for i, (inputs, targets) in enumerate(train_dl):
        inputs = to_var(inputs)
        targets = to_var(targets)
        
        # forwad pass
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # loss
        loss = criterion(outputs, targets)
        
        losses += [loss.data]
        
         
        # backward pass
        loss.backward()
        
        # update parameters
        optimizer.step()
        
        # report
        if (i + 1) % 50 == 0:
            print('Epoch [%2d/%2d], Step [%3d/%3d], Loss: %.4f'  % (epoch + 1, num_epochs, i + 1, len(train_ds) // batch_size, loss.data))
# Out:
# Epoch [ 1/10], Step [ 50/114], Loss: 0.6214
# Epoch [ 1/10], Step [100/114], Loss: 0.6001
# Epoch [ 2/10], Step [ 50/114], Loss: 0.5918
# Epoch [ 2/10], Step [100/114], Loss: 0.5735
# Epoch [ 3/10], Step [ 50/114], Loss: 0.6073
# Epoch [ 3/10], Step [100/114], Loss: 0.6154
# Epoch [ 4/10], Step [ 50/114], Loss: 0.5799
# Epoch [ 4/10], Step [100/114], Loss: 0.5721
# Epoch [ 5/10], Step [ 50/114], Loss: 0.4939
# Epoch [ 5/10], Step [100/114], Loss: 0.6900
# Epoch [ 6/10], Step [ 50/114], Loss: 0.5479
# Epoch [ 6/10], Step [100/114], Loss: 0.5281
# Epoch [ 7/10], Step [ 50/114], Loss: 0.3880
# Epoch [ 7/10], Step [100/114], Loss: 0.3991
# Epoch [ 8/10], Step [ 50/114], Loss: 0.7536
# Epoch [ 8/10], Step [100/114], Loss: 0.4349
# Epoch [ 9/10], Step [ 50/114], Loss: 0.3760
# Epoch [ 9/10], Step [100/114], Loss: 0.5002
# Epoch [10/10], Step [ 50/114], Loss: 0.4290
# Epoch [10/10], Step [100/114], Loss: 0.4344

# %%
temp=0
temp+=loss.data
print(temp)
# Out:
# tensor(0.6611)

# %%
plt.figure(figsize=(12, 4))
plt.plot(losses)
plt.xlabel('Iteration')
plt.ylabel('loss')
plt.title('Cross Entropy Loss');

# %%
plt.show()

# %% [markdown]
# ### Analyze results

# %% [markdown]
# #### Accuracy on validation data

# %%
def evaluate_model(model, dataloader):
    model.eval()  # for batch normalization layers
    corrects = 0
    for inputs, targets in dataloader:
        inputs, targets = to_var(inputs, True), to_var(targets, True)
        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)
        corrects += (preds == targets.data).sum()
    
    print('accuracy: {:.2f}'.format(100. * corrects / len(dataloader.dataset)))

# %%
evaluate_model(model, valid_dl)
# Out:
# C:\prg\deep\week1\utils.py:21: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(x, volatile=volatile)
# accuracy: 62.20

# %%
evaluate_model(model, train_dl)

# %%
visualize_model(model, train_dl)

# %%
visualize_model(model, valid_dl)

# %%
plot_errors(model, valid_dl)

# %% [markdown]
# #### Confusion matrix

# %%
y_pred, y_true = predict_class(model, valid_dl)
cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, train_ds.classes, normalize=True, figsize=(4, 4))

# %% [markdown]
# ## Overfit

# %% [markdown]
# <div class="alert alert-success">
#     <strong>What is OVERFIT? </strong>
#     <ul>
#         <li>The most important concept in ML!</li>
#         <li>Simply, it means that your model is too complex for your problem.</li>
#     </ul>
# </div>

# %% [markdown]
# <h6>What we can do about it?</h6>

# %% [markdown]
# - Regularization
# - Dropout
# - Data Augmentation
# - Transfer Learning

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# <img src='imgs/Augmentation.jpg' width='90%'/>

# %% [markdown]
# <h6>Possible Transformations:</h6>
# - Scaling
# - Rotation
# - Translation
# - Flip horizontaly
# - Random Crop
# - Color jitter
# - many more!

# %% [markdown]
# <img src='imgs/Augmentation-Examples.jpg' width='75%'/>

# %%
# Data augmentation and normalization for training
train_transforms = transforms.Compose([
    transforms.Resize((sz, sz)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.1, 0.1, 0.1, 0.01),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Just normalization for validation
valid_transforms = transforms.Compose([
    transforms.Resize((sz, sz)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_ds = datasets.ImageFolder(f'{DATA_DIR}train', train_transforms)
valid_ds = datasets.ImageFolder(f'{DATA_DIR}valid', valid_transforms)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_dl = torch.utils.data.DataLoader(valid_ds, batch_size=batch_size, shuffle=True)

train_ds_sz = len(train_ds)
valid_ds_sz = len(valid_ds)

print('Train size: {}\nValid size: {} ({:.2f})'.format(train_ds_sz, valid_ds_sz, valid_ds_sz/(train_ds_sz + valid_ds_sz)))

class_names = train_ds.classes

# %%
inputs, targets = next(iter(train_dl))     # Get a batch of training data
out = torchvision.utils.make_grid(inputs)  # Make a grid from batch
plt.figure(figsize=(16., 12.))
imshow(out, title='Augmented Images');

# %% [markdown]
# #### Look at the sizes of the images

# %%
fnames = glob.glob(f'{trn_dir}/*/*.jpg')
sizes = [Image.open(f).size for f in fnames]

hs, ws = list(zip(*sizes))

plt.figure(figsize=(12., 4.))
plt.hist(hs)
plt.hist(ws);

# %%
# create model
model = SimpleCNN()
if use_gpu:
    model = model.cuda()
    
# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9)

# train
model = train_model(model, train_dl, valid_dl, criterion, optimizer, num_epochs=5)

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# - Use a CNN already trained on different data (e.g., [ImageNet](http://www.image-net.org/))
# - Just Train the classifier weights (Last Layer)

# %% [markdown]
# <img src='imgs/transfer-learning.jpg' width='80%'/>

# %%
# load pre-trained ResNet18
model = load_pretrained_resnet50(model_path=None, num_classes=2)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.9)

# %%
model = train_model(model, train_dl, valid_dl, criterion, optimizer, scheduler, num_epochs=2)

# %%
evaluate_model(model, valid_dl)

# %%
visualize_model(model, valid_dl, num_images=6)

# %%
plot_errors(model, valid_dl)

# %% [markdown]
# ## PROGRAMMING ASSIGNMENT 1

# %% [markdown]
# <div class="alert alert-success">
#     <strong>[Plant Seeldlings Competition](https://www.kaggle.com/c/plant-seedlings-classification)</strong>
#     <img src='imgs/PlantSeedling.png'/>
#     <ul>
#         <li><strong>Objective:</strong> getting a rank among top 50% in LB.</li>
#         <li><strong>Ideas:</strong> different augmentations, different architectures, etc.</li>
#         <li><strong>Important:</strong> share your ideas and progress on Piazz.</li>
#     </ul>
# </div>
